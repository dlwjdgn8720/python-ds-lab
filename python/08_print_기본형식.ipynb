# %% [markdown]
# # print()

# %% [markdown]
# ## 1. 기본 문법
# - print(value, ..., sep='구분기호', end= '\n', flush=False)

# %%
a = 5
a
# Out:
# 5

# %%
b = 3
b
# Out:
# 3

# %%
a + b
# Out:
# 8

# %%
print(a)
print(b)
print(a+b)
# Out:
# 5
# 3
# 8

# %%
a + b
# Out:
# 8

# %%
print(1, 2, 3, sep='-') #1-2-3
# Out:
# 1-2-3

# %%
print(1, 2, 3, sep='-', flush=True) # 1-2-3
# Out:
# 1-2-3

# %%
print(a, end='\t')
print(b, end='\t')
print(a+b)
# Out:
# 5	3	8

# %%
name = '홍길동'
age = 30
#1. 콤마(,)를 사용하여 문자열 연결
print('이름:', name, '나이:', age)
# Out:
# 이름: 홍길동 나이: 30

# %%
#2. 플러스 기호(+)를 사용하여 문자열 연결, 문자열만 가능
print('이름:'+ name, '나이:'+ str(age)) # int() - 숫자로 변환, str()- 문자열로 변환
# Out:
# 이름:홍길동 나이:30

# %%
#3. % 포맷(old version)
print("이름: %s, 나이:%d" % (name, age))
# Out:
# 이름: 홍길동, 나이:30

# %%
#4. format{} 포맷 (new version)
print("이름: {}, 나이: {}".format(name, age))
# Out:
# 이름: 홍길동, 나이: 30

# %%
#5. f-string(권장)
print(f"이름: {name}, 나이:{age}")
# Out:
# 이름: 홍길동, 나이:30

# %%
# 여러 값을 출력 콤마(,) 구분
print(1, 2, 3)
print(1, 2, 3, sep=',')
# Out:
# 1 2 3
# 1,2,3

# %%
# 줄 바꿈 없이 옆으로 출력
lst = [1, 2, 3, 4, 5]
for i in lst : # 0, 1, 2, 3, 4,
    print(i, end='\t')
# Out:
# 1	2	3	4	5

# %%
# 빈 줄 출력
print()

# %%
# '*' 문자열을 50번 출력
print('*' * 50)
# Out:
# **************************************************
