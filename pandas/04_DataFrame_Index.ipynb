# %% [markdown]
# # Index란?
# - Pandas의 Index는 데이터프레임과 시리즈의 각 행(row)을 고유하게 식별하는 역할을 수행함
# - 관계형 데이터베이스의 Primary key(PK)와 유사한 개념
# - 특징
#     - 데이터 식별 역할 수행
#     - 숫자,문자열도 가능
#     - 생성 후 직접 수정 불가
#     - reset.index() 함수를 이용하여 재생성 가능

# %%
import warnings
warnings.filterwarnings(action='ignore')
import pandas as pd
import numpy as np

# %%
# Titanic 데이터셋 로드
titanic_df = pd.read_csv('data/titanic/train.csv')
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# 인덱스 재생성, reset_index()
td_reset_df = titanic_df.reset_index(inplace=False)
td_reset_df.head()
# Out:
#    index  PassengerId  Survived  Pclass  \
# 0      0            1         0       3
# 1      1            2         1       1
# 2      2            3         1       3
# 3      3            4         1       1
# 4      4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
# td_reset_df 객체의 인덱스 재생성
td_reset_df2 = td_reset_df.reset_index(inplace=False)
td_reset_df2.head(3)
# Out:
#    level_0  index  PassengerId  Survived  Pclass  \
# 0        0      0            1         0       3
# 1        1      1            2         1       1
# 2        2      2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# td_reset_df2 객체의 level_0 컬럼 삭제, 원본 반영
td_reset_df2.drop('level_0', axis=1, inplace=True) 
td_reset_df2.head()
# Out:
#    index  PassengerId  Survived  Pclass  \
# 0      0            1         0       3
# 1      1            2         1       1
# 2      2            3         1       3
# 3      3            4         1       1
# 4      4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
# td_reset_df2 객체의 0, 1, 2 인덱스 삭제, 원본 반영
td_reset_df2.drop([0, 1, 2], axis=0, inplace=True)
td_reset_df2.head()
# Out:
#    index  PassengerId  Survived  Pclass  \
# 3      3            4         1       1
# 4      4            5         0       3
# 5      5            6         0       3
# 6      6            7         0       1
# 7      7            8         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
# 6                       McCarthy, Mr. Timothy J    male  54.0      0      0
# 7                Palsson, Master. Gosta Leonard    male   2.0      3      1
#
#    Ticket     Fare Cabin Embarked
# 3  113803  53.1000  C123        S
# 4  373450   8.0500   NaN        S
# 5  330877   8.4583   NaN        Q
# 6   17463  51.8625   E46        S
# 7  349909  21.0750   NaN        S

# %%
# td_reset_df2 객체의 인덱스 재생성, 원본 반영
td_reset_df2.reset_index(inplace=True)
td_reset_df2.head()
# Out:
#    level_0  index  PassengerId  Survived  Pclass  \
# 0        3      3            4         1       1
# 1        4      4            5         0       3
# 2        5      5            6         0       3
# 3        6      6            7         0       1
# 4        7      7            8         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 1                      Allen, Mr. William Henry    male  35.0      0      0
# 2                              Moran, Mr. James    male   NaN      0      0
# 3                       McCarthy, Mr. Timothy J    male  54.0      0      0
# 4                Palsson, Master. Gosta Leonard    male   2.0      3      1
#
#    Ticket     Fare Cabin Embarked
# 0  113803  53.1000  C123        S
# 1  373450   8.0500   NaN        S
# 2  330877   8.4583   NaN        Q
# 3   17463  51.8625   E46        S
# 4  349909  21.0750   NaN        S

# %%
td_reset_df2.drop(['level_0', 'index'], axis=1, inplace=True)
td_reset_df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              4         1       1
# 1              5         0       3
# 2              6         0       3
# 3              7         0       1
# 4              8         0       3
# ..           ...       ...     ...
# 883          887         0       2
# 884          888         1       1
# 885          889         0       3
# 886          890         1       1
# 887          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 1                        Allen, Mr. William Henry    male  35.0      0      0
# 2                                Moran, Mr. James    male   NaN      0      0
# 3                         McCarthy, Mr. Timothy J    male  54.0      0      0
# 4                  Palsson, Master. Gosta Leonard    male   2.0      3      1
# ...
